# %%
# !pip3 install torch torchvision
# !pip3 install chromadb
# !pip3 install sentence-transformers scipy numpy scikit-learn
# !pip3 install pypdf
# Out:
# Requirement already satisfied: torch in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: torchvision in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (0.17.2)
# Requirement already satisfied: filelock in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from torch) (2024.10.0)
# Requirement already satisfied: numpy in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from torchvision) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: chromadb in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (0.5.18)
# Requirement already satisfied: build>=1.0.3 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (2.9.2)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (0.115.4)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.32.0)
# Requirement already satisfied: numpy>=1.22.5 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (3.7.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (1.20.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (1.28.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (1.28.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (0.49b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (1.28.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (4.67.0)
# Requirement already satisfied: overrides>=7.3.1 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (1.67.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (4.2.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (0.13.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (31.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (3.10.11)
# Requirement already satisfied: httpx>=0.27.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: packaging>=19.1 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (24.2)
# Requirement already satisfied: pyproject_hooks in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from fastapi>=0.95.2->chromadb) (0.41.2)
# Requirement already satisfied: anyio in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (4.6.2.post1)
# Requirement already satisfied: certifi in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (1.0.6)
# Requirement already satisfied: idna in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: sniffio in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.36.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: coloredlogs in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (5.28.3)
# Requirement already satisfied: sympy in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.5.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.65.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.28.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.28.0)
# Requirement already satisfied: opentelemetry-proto==1.28.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.28.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.49b0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.49b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.49b0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.49b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.49b0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.49b0)
# Requirement already satisfied: opentelemetry-util-http==0.49b0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.49b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.49b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from opentelemetry-instrumentation-asgi==0.49b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from pydantic>=1.9->chromadb) (2.23.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from rich>=10.11.0->chromadb) (2.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from tokenizers>=0.13.2->chromadb) (0.26.2)
# Requirement already satisfied: click>=8.0.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.5.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (13.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.10.0)
# Requirement already satisfied: zipp>=3.20 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.20.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: sentence-transformers in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (3.2.1)
# Requirement already satisfied: scipy in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (1.14.1)
# Requirement already satisfied: numpy in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: scikit-learn in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (1.5.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from sentence-transformers) (4.46.2)
# Requirement already satisfied: tqdm in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from sentence-transformers) (4.67.0)
# Requirement already satisfied: torch>=1.11.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from sentence-transformers) (2.2.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from sentence-transformers) (0.26.2)
# Requirement already satisfied: Pillow in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from sentence-transformers) (11.0.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: filelock in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: sympy in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.3)
# Requirement already satisfied: networkx in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.20.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pypdf in /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages (5.1.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import time
import chromadb
import json
import numpy as np
import torch

from sentence_transformers import SentenceTransformer
from concurrent.futures import ThreadPoolExecutor
# Out:
# /Users/stevenarellano/Desktop/stuff/code/papyrus/.venv/lib/python3.11/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
from utils import load_data, get_document_chunks, LinearAdapter

# %% [markdown]
# ## ChromaDB

# %%
def setup_chromadb(path="chromadb"):
    client = chromadb.PersistentClient(path=path)
    try:
        client.delete_collection("paper_collection")
    except Exception as e:
        print(f"Collection deletion error: {e}")

    collection = client.create_collection(
        "paper_collection", metadata={"hnsw:space": "cosine"})
    return collection

# %% [markdown]
# ## Data Processing and Model Prep

# %%
def add_chunks_to_collection(collection, chunks):
    def add_chunk(chunk, index):
        collection.add(documents=[chunk], ids=[f"chunk_{index}"])

    start_time = time.time()
    with ThreadPoolExecutor() as executor:
        futures = [executor.submit(add_chunk, chunk, i)
                   for i, chunk in enumerate(chunks)]
    for future in futures:
        future.result()
    print(
        f"Time taken for adding chunks: {time.time() - start_time:.2f} seconds")


def retrieve_documents_embeddings(collection, query_embedding, k=10):
    results = collection.query(
        query_embeddings=[query_embedding.tolist()],
        n_results=k
    )
    return results['documents'][0]

# %% [markdown]
# ## Metrics and Calculations

# %%
def reciprocal_rank(retrieved_docs, ground_truth, k):
    try:
        rank = retrieved_docs.index(ground_truth) + 1
        return 1.0 / rank if rank <= k else 0.0
    except ValueError:
        return 0.0


def hit_rate(retrieved_docs, ground_truth, k):
    return 1.0 if ground_truth in retrieved_docs[:k] else 0.0


def validate_embedding_model(validation_data, base_model, collection, k=10):
    hit_rates = []
    reciprocal_ranks = []
    for data_point in validation_data:
        question = data_point['question']
        ground_truth = data_point['chunk']
        question_embedding = base_model.encode(question)
        retrieved_docs = retrieve_documents_embeddings(
            collection, question_embedding, k)
        hit_rates.append(hit_rate(retrieved_docs, ground_truth, k))
        reciprocal_ranks.append(reciprocal_rank(
            retrieved_docs, ground_truth, k))
    return {
        'average_hit_rate': np.mean(hit_rates),
        'average_reciprocal_rank': np.mean(reciprocal_ranks)
    }

# %% [markdown]
# ## Adapter and Dataset Classes

# %%
def encode_query(query, base_model, adapter):
    device = next(adapter.parameters()).device
    query_emb = base_model.encode(query, convert_to_tensor=True).to(device)
    adapted_query_emb = adapter(query_emb)
    return adapted_query_emb.cpu().detach().numpy()


def evaluate_adapter(validation_data, base_model, adapter, collection, k=50):
    hit_rates, reciprocal_ranks = [], []
    for data_point in validation_data:
        question, ground_truth = data_point['question'], data_point['chunk']
        question_embedding = encode_query(question, base_model, adapter)
        retrieved_docs = retrieve_documents_embeddings(
            collection, question_embedding, k)
        hit_rates.append(hit_rate(retrieved_docs, ground_truth, k))
        reciprocal_ranks.append(reciprocal_rank(
            retrieved_docs, ground_truth, k))
    return {
        'average_hit_rate': np.mean(hit_rates),
        'average_reciprocal_rank': np.mean(reciprocal_ranks)
    }

# %% [markdown]
# # Run

# %%
with open('../globals.json') as config_file:
    config = json.load(config_file)
    pdf_path = config.get("main_pdf")

collection = setup_chromadb()
base_model = SentenceTransformer('all-MiniLM-L6-v2')

chunks = get_document_chunks(pdf_path)
add_chunks_to_collection(collection, chunks)

train_path = '../data/train.json'
validation_path = '../data/validation.json'
train_data, validation_data = load_data(train_path, validation_path)

base_results = validate_embedding_model(
    validation_data, base_model, collection)
print("Base Model - Average Hit Rate @10:", base_results['average_hit_rate'])
print("Base Model - Mean Reciprocal Rank @10:",
      base_results['average_reciprocal_rank'])

adapter = LinearAdapter(base_model.get_sentence_embedding_dimension())
adapter.load_state_dict(torch.load(
    '../adapters/linear_adapter_10epochs.pth')['adapter_state_dict'])
adapter_results = evaluate_adapter(
    validation_data, base_model, adapter, collection)
print("Adapter - Average Hit Rate @10:", adapter_results['average_hit_rate'])
print("Adapter - Mean Reciprocal Rank @10:",
      adapter_results['average_reciprocal_rank'])
# Out:
# Ignoring wrong pointing object 46 0 (offset 0)
# Ignoring wrong pointing object 48 0 (offset 0)
# Ignoring wrong pointing object 50 0 (offset 0)
# Ignoring wrong pointing object 53 0 (offset 0)
# Ignoring wrong pointing object 193 0 (offset 0)
# Ignoring wrong pointing object 195 0 (offset 0)
# Ignoring wrong pointing object 197 0 (offset 0)
# Ignoring wrong pointing object 200 0 (offset 0)
# Ignoring wrong pointing object 217 0 (offset 0)
# Ignoring wrong pointing object 219 0 (offset 0)
# Ignoring wrong pointing object 221 0 (offset 0)
# Ignoring wrong pointing object 224 0 (offset 0)
# Ignoring wrong pointing object 298 0 (offset 0)
# Ignoring wrong pointing object 300 0 (offset 0)
# Ignoring wrong pointing object 302 0 (offset 0)
# Ignoring wrong pointing object 304 0 (offset 0)
# Ignoring wrong pointing object 308 0 (offset 0)
# Ignoring wrong pointing object 310 0 (offset 0)
# Ignoring wrong pointing object 312 0 (offset 0)
# Ignoring wrong pointing object 314 0 (offset 0)
# Ignoring wrong pointing object 354 0 (offset 0)
# Ignoring wrong pointing object 356 0 (offset 0)
# Ignoring wrong pointing object 358 0 (offset 0)
# Ignoring wrong pointing object 360 0 (offset 0)
# Ignoring wrong pointing object 372 0 (offset 0)
# Ignoring wrong pointing object 374 0 (offset 0)
# Ignoring wrong pointing object 376 0 (offset 0)
# Ignoring wrong pointing object 378 0 (offset 0)
# Ignoring wrong pointing object 389 0 (offset 0)
# Ignoring wrong pointing object 391 0 (offset 0)
# Ignoring wrong pointing object 393 0 (offset 0)
# Ignoring wrong pointing object 395 0 (offset 0)
# Ignoring wrong pointing object 405 0 (offset 0)
# Ignoring wrong pointing object 407 0 (offset 0)
# Ignoring wrong pointing object 409 0 (offset 0)
# Ignoring wrong pointing object 411 0 (offset 0)
# Ignoring wrong pointing object 426 0 (offset 0)
# Ignoring wrong pointing object 428 0 (offset 0)
# Ignoring wrong pointing object 430 0 (offset 0)
# Ignoring wrong pointing object 432 0 (offset 0)
# Ignoring wrong pointing object 442 0 (offset 0)
# Ignoring wrong pointing object 444 0 (offset 0)
# Ignoring wrong pointing object 446 0 (offset 0)
# Ignoring wrong pointing object 448 0 (offset 0)
# Ignoring wrong pointing object 469 0 (offset 0)
# Ignoring wrong pointing object 471 0 (offset 0)
# Ignoring wrong pointing object 473 0 (offset 0)
# Ignoring wrong pointing object 476 0 (offset 0)
# Ignoring wrong pointing object 496 0 (offset 0)
# Ignoring wrong pointing object 498 0 (offset 0)
# Ignoring wrong pointing object 500 0 (offset 0)
# Ignoring wrong pointing object 502 0 (offset 0)
# Time taken for adding chunks: 11.89 seconds
# Base Model - Average Hit Rate @10: 0.013157894736842105
# Base Model - Mean Reciprocal Rank @10: 0.003380847953216374
# Adapter - Average Hit Rate @10: 0.019736842105263157
# Adapter - Mean Reciprocal Rank @10: 0.007080200501253133
